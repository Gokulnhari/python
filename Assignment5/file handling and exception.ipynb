# %% [markdown]
# **Write a Python program to read a file and display its contents.**

# %%
file = open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file1.txt",'w')
file.write("Hello World! \nThis is a test message:")
with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file1.txt",'r') as file:
    content = file.read()
    print(content)
file.close()
# Out:
# Hello World!
# This is a test message:

# %% [markdown]
# **Write a Python program to copy the contents of one file to another file Exercise.**

# %%
with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file1.txt", 'r') as file:
    content = file.read()

with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file2.txt", 'w') as dest:
    dest.write(content)

with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file2.txt",'r') as out: #this is to display the out from the destination file after copying.
    ret = out.read()
    print(ret)

file.close()
dest.close()
# Out:
# Hello World!
# This is a test message:

# %% [markdown]
# **Write a Python program to read the content of a file and count the total number of words in that file.**

# %%
with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/file1.txt", 'r') as file:
    content=file.read()
    print("The length of the content of the file:")
    print(content)
    print("is")
    words = content.split()
    leng = len(words)
    print(leng)
# Out:
# The length of the content of the file:
# Hello World!
# This is a test message:
# is
# 7

# %% [markdown]
# **Write a Python program that prompts the user to input a string and converts it to an integer.
#    Use try-except blocks to handle any exceptions that might occur.**

# %%
print("Enter the input string:")
string = input()
try:
    integerstring = int(string)
    print(type(integerstring))
except:
       print("the string is not an integer")
# Out:
# Enter the input string:
#  Hello Gokul
# the string is not an integer

# %% [markdown]
# **Write a Python program that prompts the user to input a list of integers and raises an exception if any of the integers in the list are negative.**

# %%
  try:
    input_string = input("Enter a list of integers separated by spaces: ")
    numbers = [int(x) for x in input_string.split()]

    for number in numbers:
      if number < 0:
        raise ValueError("The list contains negative numbers. Only positive integers are allowed.")
    else:
      print("The list of positive integers is:", numbers)
  except ValueError as e:
    print(f"Error: {e}")
# Out:
# Enter a list of integers separated by spaces:  2 5 -2
# Error: The list contains negative numbers. Only positive integers are allowed.

# %% [markdown]
# **Write a Python program that prompts the user to input a list of integers and computes the average of those integers. Use try-except blocks to handle any exceptions that might occur.use the finally clause to print a message indicating that the program has finished running.**

# %%
try:
  i = input("Enter the list of integers seprated by spaces:")
  numbers = [int(x) for x in i.split()]
  average = sum(numbers) / len(numbers)
  print("The average of the integers is:", average)
except ValueError:
  print("Invalid input. Please enter a list of integers separated by spaces.") 
finally:
  print("The program has finished running.")
# Out:
# Enter the list of integers seprated by spaces: 4 7 1
# The average of the integers is: 4.0
# The program has finished running.

# %% [markdown]
# **Write a Python program that prompts the user to input a filename and writes a string to that file. Use try-except blocks to handle any exceptions that might occur and print a welcome message if there is no exception occurred.**

# %%
i = input("Enter the name of the file:")
g = input("Enter the message that you want to write:")
try:
    with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/"+i+".txt",'w') as file:
        file.write(g)
        file.write("\nHello This is a welcome message // no exception occured:")
except FileNotFoundError:
    print("There is no such file in this directory:")


with open("C:/Users/gokul/Downloads/Telegram Desktop/Entri Elevate/Python/Assignment5/"+i+".txt",'r') as file:
    y=file.read()
print(y)
file.close()
# Out:
# Enter the name of the file: Gokul1
# Enter the message that you want to write: Hello This is you
# Hello This is you
# Hello This is a welcome message // no exception occured:
